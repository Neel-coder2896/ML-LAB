# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning</b></center>
# <center><b><h1>Lab - 3</b></center>
# <pre>

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
chipo.shape[0]
# Out:
# 4622

# %%
# Solution 2
chipo.info
# Out:
# <bound method DataFrame.info of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]>

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='str')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Number of Unique Items ?

# %%
chipo['item_name'].unique()


#number of unique
chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# ### Step 10. Which was the most-ordered item?

# %%
most_ordered=chipo.groupby('item_name')['quantity'].sum()
most_ord=most_ordered.sort_values(ascending=False)
most_ord.head(1)
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 11. How many items were orderd in total?

# %%
chipo['quantity'].sum()
# Out:
# np.int64(4972)

# %% [markdown]
# ### Step 12. Turn the item price into a float

# %% [markdown]
# #### Step 12.a. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 12.b. Create a lambda function and change the type of item price

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)

# %% [markdown]
# #### Step 12.c. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo['revenue']=(chipo['quantity']*chipo['item_price']).sum()
chipo['revenue']
# Out:
# 0       39237.02
# 1       39237.02
# 2       39237.02
# 3       39237.02
# 4       39237.02
#           ...
# 4617    39237.02
# 4618    39237.02
# 4619    39237.02
# 4620    39237.02
# 4621    39237.02
# Name: revenue, Length: 4622, dtype: float64

# %% [markdown]
# ### Step 15. How many orders were made ?

# %%
chipo['order_id'].nunique()
# Out:
# 1834

# %% [markdown]
# ### Step 17. How many different choice descriptions are there?

# %%
chipo['choice_description'].nunique()
# Out:
# 1043

# %% [markdown]
# ### Step 18. What items have been ordered more than 100 times?

# %%
chipo.groupby("item_name")['quantity'].sum().loc[lambda x:x>100]
# Out:
# item_name
# Bottled Water                   211
# Canned Soda                     126
# Canned Soft Drink               351
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chicken Salad Bowl              123
# Chicken Soft Tacos              120
# Chips                           230
# Chips and Fresh Tomato Salsa    130
# Chips and Guacamole             506
# Side of Chips                   110
# Steak Bowl                      221
# Steak Burrito                   386
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 19. What is the average revenue amount per order?

# %%
# Solution 1

chipo['revenue'] = chipo['quantity'] * chipo['item_price']
order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped.mean()['revenue']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       3 chipo['revenue'] = chipo['quantity'] * chipo['item_price']
#       4 order_grouped = chipo.groupby(by=['order_id']).sum()
# ----> 5 order_grouped.mean()['revenue']
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:14473, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14392 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#   14393 def mean(
#   14394     self,
#    (...)  14398     **kwargs,
#   14399 ) -> Series | Any:
#   14400     """
#   14401     Return the mean of the values over the requested axis.
#   14402
#    (...)  14471     dtype: float64
#   14472     """
# > 14473     result = super().mean(
#   14474         axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#   14475     )
#   14476     if isinstance(result, Series):
#   14477         result = result.__finalize__(self, method="mean")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11823 def mean(
#   11824     self,
#   11825     *,
#    (...)  11829     **kwargs,
#   11830 ) -> Series | float:
# > 11831     return self._stat_function(
#   11832         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781 nv.validate_func(name, (), kwargs)
#   11783 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11785 return self._reduce(
#   11786     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:13633, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   13629     df = df.T
#   13631 # After possibly _get_data and transposing, we are now in the
#   13632 #  simple case where we can use BlockManager.reduce
# > 13633 res = df._mgr.reduce(blk_func)
#   13634 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   13635 out.name = None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\managers.py:1681, in BlockManager.reduce(self, func)
#    1678 # If 2D, we assume that we're operating column-wise
#    1679 assert self.ndim == 2
# -> 1681 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1682 index = default_index(1)  # placeholder
#    1683 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\blocks.py:358, in Block.reduce(self, func)
#     352 @final
#     353 def reduce(self, func) -> Block:
#     354     # We will apply the function and reshape the result into a single-row
#     355     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     356     assert self.ndim == 2
# --> 358     result = func(self.values)
#     360     if self.values.ndim == 1:
#     361         res_values = result
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:13561, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   13559     if not is_1d_only_ea_dtype(values.dtype):
#   13560         return values._reduce(name, axis=1, skipna=skipna, **kwds)
# > 13561     return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   13562 else:
#   13563     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\arrays\string_.py:969, in StringArray._reduce(self, name, skipna, keepdims, axis, **kwargs)
#     966         return self._from_sequence([result], dtype=self.dtype)
#     967     return result
# --> 969 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype

# %%
# Solution 2

chipo.groupby(by=['order_id']).sum().mean()['revenue']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 # Solution 2
# ----> 3 chipo.groupby(by=['order_id']).sum().mean()['revenue']
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:14473, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14392 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#   14393 def mean(
#   14394     self,
#    (...)  14398     **kwargs,
#   14399 ) -> Series | Any:
#   14400     """
#   14401     Return the mean of the values over the requested axis.
#   14402
#    (...)  14471     dtype: float64
#   14472     """
# > 14473     result = super().mean(
#   14474         axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#   14475     )
#   14476     if isinstance(result, Series):
#   14477         result = result.__finalize__(self, method="mean")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11823 def mean(
#   11824     self,
#   11825     *,
#    (...)  11829     **kwargs,
#   11830 ) -> Series | float:
# > 11831     return self._stat_function(
#   11832         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781 nv.validate_func(name, (), kwargs)
#   11783 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11785 return self._reduce(
#   11786     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:13633, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   13629     df = df.T
#   13631 # After possibly _get_data and transposing, we are now in the
#   13632 #  simple case where we can use BlockManager.reduce
# > 13633 res = df._mgr.reduce(blk_func)
#   13634 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   13635 out.name = None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\managers.py:1681, in BlockManager.reduce(self, func)
#    1678 # If 2D, we assume that we're operating column-wise
#    1679 assert self.ndim == 2
# -> 1681 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1682 index = default_index(1)  # placeholder
#    1683 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\blocks.py:358, in Block.reduce(self, func)
#     352 @final
#     353 def reduce(self, func) -> Block:
#     354     # We will apply the function and reshape the result into a single-row
#     355     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     356     assert self.ndim == 2
# --> 358     result = func(self.values)
#     360     if self.values.ndim == 1:
#     361         res_values = result
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:13561, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   13559     if not is_1d_only_ea_dtype(values.dtype):
#   13560         return values._reduce(name, axis=1, skipna=skipna, **kwds)
# > 13561     return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   13562 else:
#   13563     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\arrays\string_.py:969, in StringArray._reduce(self, name, skipna, keepdims, axis, **kwargs)
#     966         return self._from_sequence([result], dtype=self.dtype)
#     967     return result
# --> 969 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype
