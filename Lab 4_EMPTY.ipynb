# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
#
# <center><b><h1>Lab - 4</b></center>
# <pre>

# %% [markdown]
# # Scikit-Learn (Sklearn)

# %% [markdown]
# #### **How to Import:**
#  Check Version of SkLearn:
# and Read iphone.csv

# %%
#!pip install scikit-learn

import sklearn
#print(sklearn.__version__)

import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df_iphone=pd.read_csv("iphone.csv")
df_iphone
# Out:
#    number Ipnone name  Price
# 0       8    Iphone 8    499
# 1      10    Iphone X    600
# 2      11   Iphone 11    800
# 3      12   Iphone 12    900
# 4      13   Iphone 13   1000
# 5      14   Iphone 14   1299

# %% [markdown]
# ---
# ## Dataset Splitting with `train_test_split`
#
# ### Why do we split our dataset into Training and Testing sets?**
# **Answer:**
# If we train a model on our entire dataset, we cannot verify how it performs on new, unseen data. It might just memorize the training dataset (a problem known as **Overfitting**).

# %% [markdown]
# ### How does `train_test_split` work? Show the code for splitting `iphone.csv` with a test size of 0.33.**
# We separate our features ($X$, inputs) and targets ($y$, output/label) first, then split them using a test size of 0.33.

# %%
X_iphone=df_iphone[["number"]]
Y_iphone=df_iphone["Price"]
X_iphone
#Y_iphone
# Out:
#    number
# 0       8
# 1      10
# 2      11
# 3      12
# 4      13
# 5      14

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X_iphone,Y_iphone,test_size=0.33,random_state=42)

# %% [markdown]
# ### Show exactly what `X_train`, `X_test`, `y_train`, and `y_test` look like. Explain why specific rows ended up in which set.**
# Run the following cell to inspect the resulting training and testing divisions.

# %%
print(X_train)
print("----")
print(X_test)

print("----")

print(y_train)
print("---")
print(y_test)
# Out:
#    number
# 5      14
# 2      11
# 4      13
# 3      12
# ----
#    number
# 0       8
# 1      10
# ----
# 5    1299
# 2     800
# 4    1000
# 3     900
# Name: Price, dtype: int64
# ---
# 0    499
# 1    600
# Name: Price, dtype: int64

# %% [markdown]
# # Import LinearRegression model from linear_model family

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %% [markdown]
# # Fit the data

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
#  # Predict price of iphone 18

# %%
model.predict([[18]])
# Out:
# array([1878.1])

# %% [markdown]
#  # Predict price of iphone 20 to 80

# %%
import numpy as np

# %%
Iphonenumber=np.arange(20,81).reshape(-1,1)

# %%
answer=model.predict(Iphonenumber)
answer
# Out:
# array([ 2197.5,  2357.2,  2516.9,  2676.6,  2836.3,  2996. ,  3155.7,
#         3315.4,  3475.1,  3634.8,  3794.5,  3954.2,  4113.9,  4273.6,
#         4433.3,  4593. ,  4752.7,  4912.4,  5072.1,  5231.8,  5391.5,
#         5551.2,  5710.9,  5870.6,  6030.3,  6190. ,  6349.7,  6509.4,
#         6669.1,  6828.8,  6988.5,  7148.2,  7307.9,  7467.6,  7627.3,
#         7787. ,  7946.7,  8106.4,  8266.1,  8425.8,  8585.5,  8745.2,
#         8904.9,  9064.6,  9224.3,  9384. ,  9543.7,  9703.4,  9863.1,
#        10022.8, 10182.5, 10342.2, 10501.9, 10661.6, 10821.3, 10981. ,
#        11140.7, 11300.4, 11460.1, 11619.8, 11779.5])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Iphonenumber,answer)

# %% [markdown]
#  # Predict X_Test

# %%
ans=model.predict(X_test)
ans
# Out:
# array([281.1, 600.5])

# %% [markdown]
#  # No Plot the Difference Between y_test and Answer

# %%
y_test
# Out:
# 0    499
# 1    600
# Name: Price, dtype: int64

# %%
# Predicted Points
ans
# Out:
# array([281.1, 600.5])

# %%
plt.scatter(X_test,y_test) # Actual Points
plt.scatter(X_test,ans)

# %% [markdown]
# ## Simple Linear Regression Part -2

# %% [markdown]
# ## Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# ## Step 2. Import the dataset

# %%
df=pd.read_csv("50_Startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ## Step 3 . Check the State Column

# %%
df['State'].value_counts()
# Out:
# State
# New York      17
# California    17
# Florida       16
# Name: count, dtype: int64

# %% [markdown]
# ## Step 4 . Splitting dataset in to input and output

# %%
X=df[['R&D Spend','Administration','Marketing Spend','State']]
y=df['Profit']

# %% [markdown]
# ## Step 5 . Convert state Column into Numeric Column

# %% [markdown]
# ## Step 5.1 .  Perform Transformation

# %%
x1
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0   165349.20       136897.80        471784.10          False            True
# 1   162597.70       151377.59        443898.53          False           False
# 2   153441.51       101145.55        407934.54           True           False
# 3   144372.41       118671.85        383199.62          False            True
# 4   142107.34        91391.77        366168.42           True           False
# 5   131876.90        99814.71        362861.36          False            True
# 6   134615.46       147198.87        127716.82          False           False
# 7   130298.13       145530.06        323876.68           True           False
# 8   120542.52       148718.95        311613.29          False            True
# 9   123334.88       108679.17        304981.62          False           False
# 10  101913.08       110594.11        229160.95           True           False
# ...

# %% [markdown]
# ## Step 6 . Dummy variable trap

# %%
# Already Performed using | drop_first =True

# %% [markdown]
# ## Step 7 Splitting dataset in to Train and Test

# %% [markdown]
# ## Step 8  Import LinearRegression model from linear_model family

# %% [markdown]
# ## Step 9  Fit the data

# %%
# Out:
# LinearRegression()

# %% [markdown]
# ## Step 10  Predict the data

# %% [markdown]
# ## Step 11  Display Result

# %%
# y_test and y_predict
